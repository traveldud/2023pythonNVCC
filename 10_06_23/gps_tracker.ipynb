# %%
import folium
import csv
gpsTrack = open("gps_track.txt", "r")

csvReader = csv.reader(gpsTrack)
header = csvReader.__next__()
latIndex = header.index("lat")
longIndex = header.index("long")

mapa = folium.Map(location=[40.78966141, -77.85948515], zoom_start = 12)
for row in csvReader:
    lat = row[latIndex]
    lon = row[longIndex]
    folium.Marker([lat,lon]).add_to(mapa)
    
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11f2d4d47bd3ac83ba6d3f48232a0eca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11f2d4d47bd3ac83ba6d3f48232a0eca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11f2d4d47bd3ac83ba6d3f48232a0eca = L.map(
#                 &quot;map_11f2d4d47bd3ac83ba6d3f48232a0eca&quot;,
#                 {
#                     center: [40.78966141, -77.85948515],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0441501efeec7bf1af62030dee6178c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_fec6861aae6dad1bc96767a8ef083fd1 = L.marker(
#                 [40.78966141, -77.85948515],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_475e892009bdb6583e824c05a4056a4f = L.marker(
#                 [40.78963995, -77.85954952],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_402f45b8b4dc7276ec3cbf28023097ef = L.marker(
#                 [40.78961849, -77.85957098],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_67c0d2b53859729d3e8ba369348c9864 = L.marker(
#                 [40.78953266, -77.85965681],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_9fb30a5ee8adc5657d56f35ba2705788 = L.marker(
#                 [40.78957558, -77.85972118],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_de969269ad040024c8ae1d96a5d90052 = L.marker(
#                 [40.78968287, -77.8597641],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_dfca52580fda272eeffcd5f16d4b6840 = L.marker(
#                 [40.78979015, -77.8596139],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_0d81b22debb40290e4da17d591d5afd1 = L.marker(
#                 [40.78983307, -77.8596139],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_9b988ffedf09cb5dcb6cc0733f2f4c91 = L.marker(
#                 [40.78987598, -77.85950661],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_6ece96d50b02a06b7546b662248a7c30 = L.marker(
#                 [40.78996181, -77.85946369],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_a620a816ab8dce7d95169602563e6b9d = L.marker(
#                 [40.79011202, -77.85957098],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_5795191774e7969842120728ac74155f = L.marker(
#                 [40.79015493, -77.85954952],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_dcc459d395934bfd9c3b36620ced4dab = L.marker(
#                 [40.79015493, -77.85950661],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_550546696ec1ed5937bc89de51c9b529 = L.marker(
#                 [40.79021931, -77.85929203],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_387201e3580f1230456262197a4020df = L.marker(
#                 [40.79024076, -77.85927057],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_30b499583300bce1242c728ea0063844 = L.marker(
#                 [40.79036951, -77.85907745],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_2360918141368c901baf358d6e7ada18 = L.marker(
#                 [40.79036951, -77.85909891],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_970357fc95e65e669af52224b292afab = L.marker(
#                 [40.7904768, -77.85899162],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_91bb9995f2dd23c459758d9d4bb37399 = L.marker(
#                 [40.79064846, -77.8592062],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca);
#
#
#             var marker_a1658d303c2a0da5a4a553da84b3b6ae = L.marker(
#                 [40.79069138, -77.85922766],
#                 {}
#             ).addTo(map_11f2d4d47bd3ac83ba6d3f48232a0eca)
